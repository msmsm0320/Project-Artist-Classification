# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5033343053488435450
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5726273536
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2723653116953185438
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50, VGG16, InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.preprocessing import LabelEncoder

def cutout(image, label, probability=0.5):
    if np.random.rand() < probability:
        h, w = image.shape[:2]
        size = w // 4
        x1 = np.random.randint(w)
        y1 = np.random.randint(h)
        x2 = np.clip(x1 + size, 0, w)
        y2 = np.clip(y1 + size, 0, h)
        image[y1:y2, x1:x2 :] = 0
    return image, label


df = pd.read_csv("train.csv")
label_encoder = LabelEncoder()
artist_df = df.copy()
artist_train = label_encoder.fit_transform(df['artist'].values)


artist_df['num'] = artist_train
artist_df = artist_df.drop('id', axis=1)
artist_df = artist_df.drop('img_path', axis=1)


artist_df.set_index('num', inplace=True)
artist_df = artist_df.sort_index()


artist_test_dic = artist_df['artist'].to_dict()


# 데이터 노이즈 수정
df.loc[df['id'] == 3896, 'artist'] = 'Titian'
df.loc[df['id'] == 3986, 'artist'] = 'Alfred Sisley'

X_train = df

#X_train, X_val, y_train, y_val = train_test_split(df, df['artist'].values, test_size=0.1)

print("Number of X_train: ", len(X_train))
# Out:
# Number of X_train:  5911

# %%
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(artist_train), y=artist_train)
class_weights_dict = {i: class_weights[i] for i in range(len(class_weights))}

display(class_weights_dict)

base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(244,244,3), input_tensor=None, pooling=None)

x = GlobalAveragePooling2D()(base_model.output)

predictions = Dense(50, activation='softmax')(x)

x = BatchNormalization()(x)

model = Model(inputs=base_model.input, outputs=predictions)

LearningRate = 1e-3

optimizer = Adam(learning_rate=LearningRate)

model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['acc'])

CP = ModelCheckpoint(filepath='model/' +
                     'Googlenet-{epoch:03d}-{loss:.4f}-{val_loss:.4f}.hdf5',
                     monitor='val_loss', verbose=1, save_best_only=True, mode='min')

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.25, patience=5, verbose=1, min_lr=0.000001)
CALLBACK = [CP, LR]

early_stopping = EarlyStopping(
    monitor='val_acc',
    min_delta=0.001,
    patience=10,
    verbose=1,
    restore_best_weights=True,
)


DATAGEN_TRAIN = ImageDataGenerator(
    rescale=1/255.0,
    #rotation_range=20,
    width_shift_range=0.25,
    height_shift_range=0.25,
    #shear_range=0.2,
    zoom_range=0.25,
    horizontal_flip=True,
    #vertical_flip=True,
    data_format="channels_last",
    validation_split=0.10
)


TRAIN_GENERATOR = DATAGEN_TRAIN.flow_from_dataframe(
    dataframe=X_train, x_col='img_path', y_col='artist',
    target_size=(244, 244), 
    class_mode='categorical',
    batch_size=32, shuffle=True,
    subset="training"
    #preprocessing_function=cutout
)

VALID_GENERATOR = DATAGEN_TRAIN.flow_from_dataframe(
    dataframe=X_train, x_col='img_path', y_col='artist',
    target_size=(244, 244), 
    class_mode='categorical',
    batch_size=32, shuffle=True,
    subset="validation"
    #preprocessing_function=cutout
)
# Out:
# {0: 0.5373636363636364,
#  1: 0.7208536585365853,
#  2: 0.8956060606060606,
#  3: 1.5975675675675676,
#  4: 0.8956060606060606,
#  5: 1.8471875,
#  6: 3.694375,
#  7: 2.003728813559322,
#  8: 2.3644,
#  9: 1.4595061728395062,
#  10: 0.24126530612244898,
#  11: 1.906774193548387,
#  12: 2.686818181818182,
#  13: 1.8187692307692307,
#  14: 4.546923076923077,
#  15: 0.5795098039215686,
#  16: 1.4073809523809524,
#  17: 3.9406666666666665,
#  18: 1.6419444444444444,
#  19: 1.7133333333333334,
#  20: 2.814761904761905,
#  21: 0.9770247933884297,
#  22: 2.2734615384615386,
#  23: 1.9380327868852458,
#  24: 1.028,
#  25: 5.62952380952381,
#  26: 1.8471875,
#  27: 1.5555263157894736,
#  28: 1.299120879120879,
#  29: 1.1704950495049504,
#  30: 0.6833526011560693,
#  31: 3.4770588235294118,
#  32: 1.001864406779661,
#  33: 0.39016501650165014,
#  34: 3.5824242424242425,
#  35: 0.5373636363636364,
#  36: 0.8325352112676057,
#  37: 1.218762886597938,
#  38: 0.5073819742489271,
#  39: 2.003728813559322,
#  40: 1.3908235294117648,
#  41: 1.6194520547945206,
#  42: 0.6531491712707183,
#  43: 0.862919708029197,
#  44: 1.1941414141414142,
#  45: 0.9851666666666666,
#  46: 0.6833526011560693,
#  47: 1.9703333333333333,
#  48: 0.18794912559618443,
#  49: 2.686818181818182}
# Found 5320 validated image filenames belonging to 50 classes.
# Found 591 validated image filenames belonging to 50 classes.

# %%
history = model.fit(
    TRAIN_GENERATOR,
    epochs=200,
    callbacks=CALLBACK,
    shuffle=True,
    validation_data=VALID_GENERATOR,
    class_weight=class_weights_dict
)
# Out:
# WARNING:tensorflow:From C:\Users\User\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/200
# 167/167 [==============================] - 66s 353ms/step - loss: 3.6960 - acc: 0.0680 - val_loss: 38.7420 - val_acc: 0.0152
#
# Epoch 00001: val_loss improved from inf to 38.74197, saving model to model\Googlenet-001-3.6960-38.7420.hdf5
# Epoch 2/200
# 167/167 [==============================] - 61s 363ms/step - loss: 3.2103 - acc: 0.1372 - val_loss: 8.1278 - val_acc: 0.0135
#
# Epoch 00002: val_loss improved from 38.74197 to 8.12785, saving model to model\Googlenet-002-3.2103-8.1278.hdf5
# Epoch 3/200
# 167/167 [==============================] - 60s 360ms/step - loss: 2.9078 - acc: 0.1923 - val_loss: 8.3110 - val_acc: 0.0220
#
# Epoch 00003: val_loss did not improve from 8.12785
# Epoch 4/200
# 167/167 [==============================] - 60s 360ms/step - loss: 2.6774 - acc: 0.2376 - val_loss: 3.5524 - val_acc: 0.1726
#
# Epoch 00004: val_loss improved from 8.12785 to 3.55237, saving model to model\Googlenet-004-2.6774-3.5524.hdf5
# Epoch 5/200
# 167/167 [==============================] - 61s 362ms/step - loss: 2.4797 - acc: 0.2741 - val_loss: 4.8402 - val_acc: 0.1168
#
# Epoch 00005: val_loss did not improve from 3.55237
# Epoch 6/200
# 167/167 [==============================] - 61s 361ms/step - loss: 2.3692 - acc: 0.2855 - val_loss: 3.1840 - val_acc: 0.2183
#
# Epoch 00006: val_loss improved from 3.55237 to 3.18395, saving model to model\Googlenet-006-2.3692-3.1840.hdf5
# Epoch 7/200
# 167/167 [==============================] - 61s 362ms/step - loss: 2.1891 - acc: 0.3158 - val_loss: 4.3401 - val_acc: 0.1472
#
# Epoch 00007: val_loss did not improve from 3.18395
# Epoch 8/200
# 167/167 [==============================] - 61s 361ms/step - loss: 2.0871 - acc: 0.3491 - val_loss: 4.5015 - val_acc: 0.1624
#
# Epoch 00008: val_loss did not improve from 3.18395
# Epoch 9/200
# 167/167 [==============================] - 60s 360ms/step - loss: 1.9744 - acc: 0.3859 - val_loss: 3.5694 - val_acc: 0.1997
#
# Epoch 00009: val_loss did not improve from 3.18395
# Epoch 10/200
# 167/167 [==============================] - 60s 361ms/step - loss: 1.9897 - acc: 0.3673 - val_loss: 3.3199 - val_acc: 0.2352
#
# Epoch 00010: val_loss did not improve from 3.18395
# Epoch 11/200
# 167/167 [==============================] - 61s 361ms/step - loss: 1.8182 - acc: 0.4086 - val_loss: 3.5498 - val_acc: 0.2200
#
# Epoch 00011: val_loss did not improve from 3.18395
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/200
# 167/167 [==============================] - 61s 361ms/step - loss: 1.4757 - acc: 0.4863 - val_loss: 2.1038 - val_acc: 0.4162
#
# Epoch 00012: val_loss improved from 3.18395 to 2.10383, saving model to model\Googlenet-012-1.4757-2.1038.hdf5
# Epoch 13/200
# 167/167 [==============================] - 61s 362ms/step - loss: 1.3350 - acc: 0.5192 - val_loss: 1.9228 - val_acc: 0.4653
#
# Epoch 00013: val_loss improved from 2.10383 to 1.92276, saving model to model\Googlenet-013-1.3350-1.9228.hdf5
# Epoch 14/200
# 167/167 [==============================] - 61s 362ms/step - loss: 1.2664 - acc: 0.5374 - val_loss: 2.0891 - val_acc: 0.4298
#
# Epoch 00014: val_loss did not improve from 1.92276
# Epoch 15/200
# 167/167 [==============================] - 61s 361ms/step - loss: 1.1881 - acc: 0.5609 - val_loss: 2.2226 - val_acc: 0.4010
#
# Epoch 00015: val_loss did not improve from 1.92276
# Epoch 16/200
# 167/167 [==============================] - 61s 362ms/step - loss: 1.1287 - acc: 0.5679 - val_loss: 2.1458 - val_acc: 0.4349
#
# Epoch 00016: val_loss did not improve from 1.92276
# Epoch 17/200
# 167/167 [==============================] - 61s 362ms/step - loss: 1.0869 - acc: 0.5876 - val_loss: 1.9342 - val_acc: 0.4687
#
# Epoch 00017: val_loss did not improve from 1.92276
# Epoch 18/200
# 167/167 [==============================] - 61s 363ms/step - loss: 1.0533 - acc: 0.5895 - val_loss: 2.0551 - val_acc: 0.4501
#
# Epoch 00018: val_loss did not improve from 1.92276
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 19/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.9021 - acc: 0.6244 - val_loss: 1.7788 - val_acc: 0.5093
#
# Epoch 00019: val_loss improved from 1.92276 to 1.77883, saving model to model\Googlenet-019-0.9021-1.7788.hdf5
# Epoch 20/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.8338 - acc: 0.6523 - val_loss: 1.7515 - val_acc: 0.5347
#
# Epoch 00020: val_loss improved from 1.77883 to 1.75150, saving model to model\Googlenet-020-0.8338-1.7515.hdf5
# Epoch 21/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.7838 - acc: 0.6711 - val_loss: 1.7028 - val_acc: 0.5415
#
# Epoch 00021: val_loss improved from 1.75150 to 1.70277, saving model to model\Googlenet-021-0.7838-1.7028.hdf5
# Epoch 22/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.7577 - acc: 0.6799 - val_loss: 1.7570 - val_acc: 0.5161
#
# Epoch 00022: val_loss did not improve from 1.70277
# Epoch 23/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.7189 - acc: 0.6831 - val_loss: 1.6359 - val_acc: 0.5584
#
# Epoch 00023: val_loss improved from 1.70277 to 1.63588, saving model to model\Googlenet-023-0.7189-1.6359.hdf5
# Epoch 24/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.6665 - acc: 0.7036 - val_loss: 1.7420 - val_acc: 0.5398
#
# Epoch 00024: val_loss did not improve from 1.63588
# Epoch 25/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.6487 - acc: 0.7058 - val_loss: 1.7398 - val_acc: 0.5702
#
# Epoch 00025: val_loss did not improve from 1.63588
# Epoch 26/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.6135 - acc: 0.7211 - val_loss: 1.8003 - val_acc: 0.5533
#
# Epoch 00026: val_loss did not improve from 1.63588
# Epoch 27/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.5939 - acc: 0.7276 - val_loss: 1.7843 - val_acc: 0.5212
#
# Epoch 00027: val_loss did not improve from 1.63588
# Epoch 28/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.5751 - acc: 0.7293 - val_loss: 1.8405 - val_acc: 0.5381
#
# Epoch 00028: val_loss did not improve from 1.63588
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 29/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.5154 - acc: 0.7506 - val_loss: 1.7843 - val_acc: 0.5448
#
# Epoch 00029: val_loss did not improve from 1.63588
# Epoch 30/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4958 - acc: 0.7615 - val_loss: 1.7391 - val_acc: 0.5195
#
# Epoch 00030: val_loss did not improve from 1.63588
# Epoch 31/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.4935 - acc: 0.7664 - val_loss: 1.8180 - val_acc: 0.5499
#
# Epoch 00031: val_loss did not improve from 1.63588
# Epoch 32/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.4936 - acc: 0.7724 - val_loss: 1.7426 - val_acc: 0.5601
#
# Epoch 00032: val_loss did not improve from 1.63588
# Epoch 33/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4664 - acc: 0.7758 - val_loss: 1.7732 - val_acc: 0.5482
#
# Epoch 00033: val_loss did not improve from 1.63588
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 34/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4882 - acc: 0.7662 - val_loss: 1.7065 - val_acc: 0.5482
#
# Epoch 00034: val_loss did not improve from 1.63588
# Epoch 35/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4452 - acc: 0.7748 - val_loss: 1.7480 - val_acc: 0.5787
#
# Epoch 00035: val_loss did not improve from 1.63588
# Epoch 36/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4586 - acc: 0.7758 - val_loss: 1.7560 - val_acc: 0.5567
#
# Epoch 00036: val_loss did not improve from 1.63588
# Epoch 37/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4481 - acc: 0.7825 - val_loss: 1.7263 - val_acc: 0.5787
#
# Epoch 00037: val_loss did not improve from 1.63588
# Epoch 38/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4334 - acc: 0.7840 - val_loss: 1.8020 - val_acc: 0.5668
#
# Epoch 00038: val_loss did not improve from 1.63588
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 39/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4571 - acc: 0.7737 - val_loss: 1.6914 - val_acc: 0.5651
#
# Epoch 00039: val_loss did not improve from 1.63588
# Epoch 40/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4432 - acc: 0.7771 - val_loss: 1.6871 - val_acc: 0.5567
#
# Epoch 00040: val_loss did not improve from 1.63588
# Epoch 41/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4419 - acc: 0.7829 - val_loss: 1.7694 - val_acc: 0.5516
#
# Epoch 00041: val_loss did not improve from 1.63588
# Epoch 42/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4404 - acc: 0.7865 - val_loss: 1.7242 - val_acc: 0.5601
#
# Epoch 00042: val_loss did not improve from 1.63588
# Epoch 43/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4400 - acc: 0.7801 - val_loss: 1.6809 - val_acc: 0.5668
#
# Epoch 00043: val_loss did not improve from 1.63588
# Epoch 44/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4344 - acc: 0.7823 - val_loss: 1.7045 - val_acc: 0.5651
#
# Epoch 00044: val_loss did not improve from 1.63588
# Epoch 45/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4493 - acc: 0.7805 - val_loss: 1.7244 - val_acc: 0.5736
#
# Epoch 00045: val_loss did not improve from 1.63588
# Epoch 46/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4405 - acc: 0.7914 - val_loss: 1.7624 - val_acc: 0.5668
#
# Epoch 00046: val_loss did not improve from 1.63588
# Epoch 47/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4314 - acc: 0.7840 - val_loss: 1.7331 - val_acc: 0.5685
#
# Epoch 00047: val_loss did not improve from 1.63588
# Epoch 48/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4353 - acc: 0.7827 - val_loss: 1.7354 - val_acc: 0.5448
#
# Epoch 00048: val_loss did not improve from 1.63588
# Epoch 49/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4298 - acc: 0.7936 - val_loss: 1.7420 - val_acc: 0.5702
#
# Epoch 00049: val_loss did not improve from 1.63588
# Epoch 50/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4335 - acc: 0.7868 - val_loss: 1.6862 - val_acc: 0.5533
#
# Epoch 00050: val_loss did not improve from 1.63588
# Epoch 51/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4306 - acc: 0.7912 - val_loss: 1.7812 - val_acc: 0.5838
#
# Epoch 00051: val_loss did not improve from 1.63588
# Epoch 52/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4397 - acc: 0.7874 - val_loss: 1.6813 - val_acc: 0.5550
#
# Epoch 00052: val_loss did not improve from 1.63588
# Epoch 53/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4273 - acc: 0.7915 - val_loss: 1.6523 - val_acc: 0.5685
#
# Epoch 00053: val_loss did not improve from 1.63588
# Epoch 54/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4363 - acc: 0.7880 - val_loss: 1.7082 - val_acc: 0.5821
#
# Epoch 00054: val_loss did not improve from 1.63588
# Epoch 55/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.4266 - acc: 0.7880 - val_loss: 1.7432 - val_acc: 0.5651
#
# Epoch 00055: val_loss did not improve from 1.63588
# Epoch 56/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4341 - acc: 0.7904 - val_loss: 1.6929 - val_acc: 0.5702
#
# Epoch 00056: val_loss did not improve from 1.63588
# Epoch 57/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4450 - acc: 0.7840 - val_loss: 1.7731 - val_acc: 0.5753
#
# Epoch 00057: val_loss did not improve from 1.63588
# Epoch 58/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.4348 - acc: 0.7868 - val_loss: 1.6765 - val_acc: 0.5668
#
# Epoch 00058: val_loss did not improve from 1.63588
# Epoch 59/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4255 - acc: 0.7936 - val_loss: 1.7380 - val_acc: 0.5668
#
# Epoch 00059: val_loss did not improve from 1.63588
# Epoch 60/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4353 - acc: 0.7846 - val_loss: 1.7078 - val_acc: 0.5567
#
# Epoch 00060: val_loss did not improve from 1.63588
# Epoch 61/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4427 - acc: 0.7833 - val_loss: 1.7352 - val_acc: 0.5584
#
# Epoch 00061: val_loss did not improve from 1.63588
# Epoch 62/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4355 - acc: 0.7921 - val_loss: 1.7691 - val_acc: 0.5550
#
# Epoch 00062: val_loss did not improve from 1.63588
# Epoch 63/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4259 - acc: 0.7902 - val_loss: 1.7440 - val_acc: 0.5719
#
# Epoch 00063: val_loss did not improve from 1.63588
# Epoch 64/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4339 - acc: 0.7870 - val_loss: 1.7771 - val_acc: 0.5702
#
# Epoch 00064: val_loss did not improve from 1.63588
# Epoch 65/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4509 - acc: 0.7846 - val_loss: 1.7823 - val_acc: 0.5618
#
# Epoch 00065: val_loss did not improve from 1.63588
# Epoch 66/200
# 167/167 [==============================] - 60s 363ms/step - loss: 0.4100 - acc: 0.7912 - val_loss: 1.7217 - val_acc: 0.5685
#
# Epoch 00066: val_loss did not improve from 1.63588
# Epoch 67/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4314 - acc: 0.7883 - val_loss: 1.7209 - val_acc: 0.5618
#
# Epoch 00067: val_loss did not improve from 1.63588
# Epoch 68/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4335 - acc: 0.7910 - val_loss: 1.7257 - val_acc: 0.5736
#
# Epoch 00068: val_loss did not improve from 1.63588
# Epoch 69/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4279 - acc: 0.7846 - val_loss: 1.7260 - val_acc: 0.5821
#
# Epoch 00069: val_loss did not improve from 1.63588
# Epoch 70/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4267 - acc: 0.7889 - val_loss: 1.6762 - val_acc: 0.5702
#
# Epoch 00070: val_loss did not improve from 1.63588
# Epoch 71/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4272 - acc: 0.7861 - val_loss: 1.6757 - val_acc: 0.5804
#
# Epoch 00071: val_loss did not improve from 1.63588
# Epoch 72/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4096 - acc: 0.7936 - val_loss: 1.7141 - val_acc: 0.5567
#
# Epoch 00072: val_loss did not improve from 1.63588
# Epoch 73/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4072 - acc: 0.7974 - val_loss: 1.7467 - val_acc: 0.5567
#
# Epoch 00073: val_loss did not improve from 1.63588
# Epoch 74/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4386 - acc: 0.7806 - val_loss: 1.7302 - val_acc: 0.5702
#
# Epoch 00074: val_loss did not improve from 1.63588
# Epoch 75/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4344 - acc: 0.7915 - val_loss: 1.7404 - val_acc: 0.5719
#
# Epoch 00075: val_loss did not improve from 1.63588
# Epoch 76/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4267 - acc: 0.7955 - val_loss: 1.7423 - val_acc: 0.5567
#
# Epoch 00076: val_loss did not improve from 1.63588
# Epoch 77/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4403 - acc: 0.7801 - val_loss: 1.6921 - val_acc: 0.5685
#
# Epoch 00077: val_loss did not improve from 1.63588
# Epoch 78/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4223 - acc: 0.7983 - val_loss: 1.7297 - val_acc: 0.5787
#
# Epoch 00078: val_loss did not improve from 1.63588
# Epoch 79/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.4234 - acc: 0.7880 - val_loss: 1.7272 - val_acc: 0.5635
#
# Epoch 00079: val_loss did not improve from 1.63588
# Epoch 80/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4177 - acc: 0.7923 - val_loss: 1.6663 - val_acc: 0.5770
#
# Epoch 00080: val_loss did not improve from 1.63588
# Epoch 81/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4188 - acc: 0.7944 - val_loss: 1.6954 - val_acc: 0.5753
#
# Epoch 00081: val_loss did not improve from 1.63588
# Epoch 82/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4158 - acc: 0.7878 - val_loss: 1.7739 - val_acc: 0.5685
#
# Epoch 00082: val_loss did not improve from 1.63588
# Epoch 83/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.4303 - acc: 0.7900 - val_loss: 1.6810 - val_acc: 0.5905
#
# Epoch 00083: val_loss did not improve from 1.63588
# Epoch 84/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4269 - acc: 0.7949 - val_loss: 1.7056 - val_acc: 0.5838
#
# Epoch 00084: val_loss did not improve from 1.63588
# Epoch 85/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.4030 - acc: 0.8000 - val_loss: 1.7570 - val_acc: 0.5448
#
# Epoch 00085: val_loss did not improve from 1.63588
# Epoch 86/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4279 - acc: 0.7940 - val_loss: 1.7273 - val_acc: 0.5770
#
# Epoch 00086: val_loss did not improve from 1.63588
# Epoch 87/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.4156 - acc: 0.7970 - val_loss: 1.7792 - val_acc: 0.5533
#
# Epoch 00087: val_loss did not improve from 1.63588
# Epoch 88/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4428 - acc: 0.7846 - val_loss: 1.7226 - val_acc: 0.5702
#
# Epoch 00088: val_loss did not improve from 1.63588
# Epoch 89/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4346 - acc: 0.7874 - val_loss: 1.6482 - val_acc: 0.5584
#
# Epoch 00089: val_loss did not improve from 1.63588
# Epoch 90/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.4289 - acc: 0.7867 - val_loss: 1.7358 - val_acc: 0.5770
#
# Epoch 00090: val_loss did not improve from 1.63588
# Epoch 91/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4368 - acc: 0.7863 - val_loss: 1.7766 - val_acc: 0.5550
#
# Epoch 00091: val_loss did not improve from 1.63588
# Epoch 92/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.4288 - acc: 0.7917 - val_loss: 1.7341 - val_acc: 0.5601
#
# Epoch 00092: val_loss did not improve from 1.63588
# Epoch 93/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4096 - acc: 0.7987 - val_loss: 1.7068 - val_acc: 0.5770
#
# Epoch 00093: val_loss did not improve from 1.63588
# Epoch 94/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4173 - acc: 0.7883 - val_loss: 1.7227 - val_acc: 0.5719
#
# Epoch 00094: val_loss did not improve from 1.63588
# Epoch 95/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.3960 - acc: 0.7959 - val_loss: 1.7177 - val_acc: 0.5668
#
# Epoch 00095: val_loss did not improve from 1.63588
# Epoch 96/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4308 - acc: 0.7897 - val_loss: 1.6996 - val_acc: 0.5787
#
# Epoch 00096: val_loss did not improve from 1.63588
# Epoch 97/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4277 - acc: 0.7853 - val_loss: 1.7529 - val_acc: 0.5601
#
# Epoch 00097: val_loss did not improve from 1.63588
# Epoch 98/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4203 - acc: 0.7895 - val_loss: 1.7449 - val_acc: 0.5719
#
# Epoch 00098: val_loss did not improve from 1.63588
# Epoch 99/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4195 - acc: 0.7885 - val_loss: 1.7395 - val_acc: 0.5719
#
# Epoch 00099: val_loss did not improve from 1.63588
# Epoch 100/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.4027 - acc: 0.7929 - val_loss: 1.7572 - val_acc: 0.5702
#
# Epoch 00100: val_loss did not improve from 1.63588
# Epoch 101/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4098 - acc: 0.7987 - val_loss: 1.7469 - val_acc: 0.5516
#
# Epoch 00101: val_loss did not improve from 1.63588
# Epoch 102/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4276 - acc: 0.7868 - val_loss: 1.7062 - val_acc: 0.5618
#
# Epoch 00102: val_loss did not improve from 1.63588
# Epoch 103/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4194 - acc: 0.7906 - val_loss: 1.6739 - val_acc: 0.5685
#
# Epoch 00103: val_loss did not improve from 1.63588
# Epoch 104/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4040 - acc: 0.7992 - val_loss: 1.6969 - val_acc: 0.5736
#
# Epoch 00104: val_loss did not improve from 1.63588
# Epoch 105/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4041 - acc: 0.7957 - val_loss: 1.7241 - val_acc: 0.5533
#
# Epoch 00105: val_loss did not improve from 1.63588
# Epoch 106/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4107 - acc: 0.7977 - val_loss: 1.6940 - val_acc: 0.5854
#
# Epoch 00106: val_loss did not improve from 1.63588
# Epoch 107/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.3929 - acc: 0.8032 - val_loss: 1.7339 - val_acc: 0.5584
#
# Epoch 00107: val_loss did not improve from 1.63588
# Epoch 108/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4196 - acc: 0.7880 - val_loss: 1.6501 - val_acc: 0.5854
#
# Epoch 00108: val_loss did not improve from 1.63588
# Epoch 109/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4054 - acc: 0.7964 - val_loss: 1.7534 - val_acc: 0.5516
#
# Epoch 00109: val_loss did not improve from 1.63588
# Epoch 110/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4002 - acc: 0.7970 - val_loss: 1.6829 - val_acc: 0.5635
#
# Epoch 00110: val_loss did not improve from 1.63588
# Epoch 111/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.3790 - acc: 0.8083 - val_loss: 1.7310 - val_acc: 0.5719
#
# Epoch 00111: val_loss did not improve from 1.63588
# Epoch 112/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4197 - acc: 0.7904 - val_loss: 1.7294 - val_acc: 0.5601
#
# Epoch 00112: val_loss did not improve from 1.63588
# Epoch 113/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.4110 - acc: 0.7945 - val_loss: 1.6684 - val_acc: 0.5635
#
# Epoch 00113: val_loss did not improve from 1.63588
# Epoch 114/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.3883 - acc: 0.8066 - val_loss: 1.7346 - val_acc: 0.5482
#
# Epoch 00114: val_loss did not improve from 1.63588
# Epoch 115/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.3900 - acc: 0.8086 - val_loss: 1.7555 - val_acc: 0.5651
#
# Epoch 00115: val_loss did not improve from 1.63588
# Epoch 116/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.3909 - acc: 0.7985 - val_loss: 1.6906 - val_acc: 0.5618
#
# Epoch 00116: val_loss did not improve from 1.63588
# Epoch 117/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4137 - acc: 0.7938 - val_loss: 1.6971 - val_acc: 0.5787
#
# Epoch 00117: val_loss did not improve from 1.63588
# Epoch 118/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.4011 - acc: 0.8006 - val_loss: 1.7605 - val_acc: 0.5719
#
# Epoch 00118: val_loss did not improve from 1.63588
# Epoch 119/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4065 - acc: 0.8011 - val_loss: 1.7777 - val_acc: 0.5567
#
# Epoch 00119: val_loss did not improve from 1.63588
# Epoch 120/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.3969 - acc: 0.8024 - val_loss: 1.7443 - val_acc: 0.5702
#
# Epoch 00120: val_loss did not improve from 1.63588
# Epoch 121/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.3824 - acc: 0.8085 - val_loss: 1.7241 - val_acc: 0.5635
#
# Epoch 00121: val_loss did not improve from 1.63588
# Epoch 122/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4156 - acc: 0.7908 - val_loss: 1.7695 - val_acc: 0.5635
#
# Epoch 00122: val_loss did not improve from 1.63588
# Epoch 123/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.4066 - acc: 0.7977 - val_loss: 1.7647 - val_acc: 0.5685
#
# Epoch 00123: val_loss did not improve from 1.63588
# Epoch 124/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4003 - acc: 0.7961 - val_loss: 1.6926 - val_acc: 0.5821
#
# Epoch 00124: val_loss did not improve from 1.63588
# Epoch 125/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.3819 - acc: 0.8039 - val_loss: 1.7632 - val_acc: 0.5668
#
# Epoch 00125: val_loss did not improve from 1.63588
# Epoch 126/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4105 - acc: 0.7989 - val_loss: 1.6958 - val_acc: 0.5753
#
# Epoch 00126: val_loss did not improve from 1.63588
# Epoch 127/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4038 - acc: 0.8021 - val_loss: 1.7745 - val_acc: 0.5584
#
# Epoch 00127: val_loss did not improve from 1.63588
# Epoch 128/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.3864 - acc: 0.8017 - val_loss: 1.7096 - val_acc: 0.5719
#
# Epoch 00128: val_loss did not improve from 1.63588
# Epoch 129/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4035 - acc: 0.7968 - val_loss: 1.7885 - val_acc: 0.5533
#
# Epoch 00129: val_loss did not improve from 1.63588
# Epoch 130/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.3953 - acc: 0.7998 - val_loss: 1.7219 - val_acc: 0.5702
#
# Epoch 00130: val_loss did not improve from 1.63588
# Epoch 131/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4038 - acc: 0.7953 - val_loss: 1.7841 - val_acc: 0.5651
#
# Epoch 00131: val_loss did not improve from 1.63588
# Epoch 132/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.3994 - acc: 0.8073 - val_loss: 1.7735 - val_acc: 0.5736
#
# Epoch 00132: val_loss did not improve from 1.63588
# Epoch 133/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4061 - acc: 0.7992 - val_loss: 1.6965 - val_acc: 0.5415
#
# Epoch 00133: val_loss did not improve from 1.63588
# Epoch 134/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.4075 - acc: 0.8041 - val_loss: 1.7578 - val_acc: 0.5618
#
# Epoch 00134: val_loss did not improve from 1.63588
# Epoch 135/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.3826 - acc: 0.8055 - val_loss: 1.7355 - val_acc: 0.5685
#
# Epoch 00135: val_loss did not improve from 1.63588
# Epoch 136/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.3892 - acc: 0.8036 - val_loss: 1.7206 - val_acc: 0.5651
#
# Epoch 00136: val_loss did not improve from 1.63588
# Epoch 137/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4123 - acc: 0.7910 - val_loss: 1.7580 - val_acc: 0.5668
#
# Epoch 00137: val_loss did not improve from 1.63588
# Epoch 138/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.4092 - acc: 0.7955 - val_loss: 1.7313 - val_acc: 0.5753
#
# Epoch 00138: val_loss did not improve from 1.63588
# Epoch 139/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.3950 - acc: 0.8024 - val_loss: 1.7968 - val_acc: 0.5533
#
# Epoch 00139: val_loss did not improve from 1.63588
# Epoch 140/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.3858 - acc: 0.8017 - val_loss: 1.7306 - val_acc: 0.5804
#
# Epoch 00140: val_loss did not improve from 1.63588
# Epoch 141/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.4014 - acc: 0.7951 - val_loss: 1.7239 - val_acc: 0.5431
#
# Epoch 00141: val_loss did not improve from 1.63588
# Epoch 142/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.3886 - acc: 0.8039 - val_loss: 1.7026 - val_acc: 0.5651
#
# Epoch 00142: val_loss did not improve from 1.63588
# Epoch 143/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.3881 - acc: 0.8045 - val_loss: 1.7852 - val_acc: 0.5550
#
# Epoch 00143: val_loss did not improve from 1.63588
# Epoch 144/200
# 167/167 [==============================] - 61s 363ms/step - loss: 0.4012 - acc: 0.7989 - val_loss: 1.6949 - val_acc: 0.5804
#
# Epoch 00144: val_loss did not improve from 1.63588
# Epoch 145/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.3793 - acc: 0.8068 - val_loss: 1.7545 - val_acc: 0.5584
#
# Epoch 00145: val_loss did not improve from 1.63588
# Epoch 146/200
# 167/167 [==============================] - 60s 361ms/step - loss: 0.4148 - acc: 0.8002 - val_loss: 1.7027 - val_acc: 0.5651
#
# Epoch 00146: val_loss did not improve from 1.63588
# Epoch 147/200
# 167/167 [==============================] - 60s 360ms/step - loss: 0.3931 - acc: 0.8030 - val_loss: 1.7059 - val_acc: 0.5804
#
# Epoch 00147: val_loss did not improve from 1.63588
# Epoch 148/200
# 167/167 [==============================] - 61s 362ms/step - loss: 0.3977 - acc: 0.8013 - val_loss: 1.7511 - val_acc: 0.5635
#
# Epoch 00148: val_loss did not improve from 1.63588
# Epoch 149/200
# 167/167 [==============================] - 61s 361ms/step - loss: 0.3913 - acc: 0.8071 - val_loss: 1.6997 - val_acc: 0.5871
#
# Epoch 00149: val_loss did not improve from 1.63588
# Epoch 150/200
# 167/167 [==============================] - 64s 384ms/step - loss: 0.3991 - acc: 0.8051 - val_loss: 1.7393 - val_acc: 0.5651
#
# Epoch 00150: val_loss did not improve from 1.63588
# Epoch 151/200
# 167/167 [==============================] - 63s 374ms/step - loss: 0.3838 - acc: 0.8055 - val_loss: 1.7182 - val_acc: 0.5787
#
# Epoch 00151: val_loss did not improve from 1.63588
# Epoch 152/200
# 167/167 [==============================] - 61s 366ms/step - loss: 0.3893 - acc: 0.8002 - val_loss: 1.7309 - val_acc: 0.5736
#
# Epoch 00152: val_loss did not improve from 1.63588
# Epoch 153/200
# 167/167 [==============================] - 61s 365ms/step - loss: 0.3794 - acc: 0.8034 - val_loss: 1.7320 - val_acc: 0.5550
#
# Epoch 00153: val_loss did not improve from 1.63588
# Epoch 154/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.4052 - acc: 0.8006 - val_loss: 1.7639 - val_acc: 0.5685
#
# Epoch 00154: val_loss did not improve from 1.63588
# Epoch 155/200
# 167/167 [==============================] - 61s 365ms/step - loss: 0.3809 - acc: 0.8043 - val_loss: 1.7416 - val_acc: 0.5415
#
# Epoch 00155: val_loss did not improve from 1.63588
# Epoch 156/200
# 167/167 [==============================] - 61s 366ms/step - loss: 0.3846 - acc: 0.8075 - val_loss: 1.8217 - val_acc: 0.5702
#
# Epoch 00156: val_loss did not improve from 1.63588
# Epoch 157/200
# 167/167 [==============================] - 61s 365ms/step - loss: 0.3872 - acc: 0.8041 - val_loss: 1.7118 - val_acc: 0.5719
#
# Epoch 00157: val_loss did not improve from 1.63588
# Epoch 158/200
# 167/167 [==============================] - 61s 365ms/step - loss: 0.4127 - acc: 0.7983 - val_loss: 1.7254 - val_acc: 0.5770
#
# Epoch 00158: val_loss did not improve from 1.63588
# Epoch 159/200
# 167/167 [==============================] - 61s 366ms/step - loss: 0.3782 - acc: 0.8071 - val_loss: 1.7467 - val_acc: 0.5465
#
# Epoch 00159: val_loss did not improve from 1.63588
# Epoch 160/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.3920 - acc: 0.8045 - val_loss: 1.7823 - val_acc: 0.5431
#
# Epoch 00160: val_loss did not improve from 1.63588
# Epoch 161/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.3806 - acc: 0.8071 - val_loss: 1.6853 - val_acc: 0.5753
#
# Epoch 00161: val_loss did not improve from 1.63588
# Epoch 162/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.3991 - acc: 0.8030 - val_loss: 1.7438 - val_acc: 0.5770
#
# Epoch 00162: val_loss did not improve from 1.63588
# Epoch 163/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.3854 - acc: 0.8066 - val_loss: 1.6737 - val_acc: 0.5719
#
# Epoch 00163: val_loss did not improve from 1.63588
# Epoch 164/200
# 167/167 [==============================] - 61s 364ms/step - loss: 0.3811 - acc: 0.8077 - val_loss: 1.7159 - val_acc: 0.5685
#
# Epoch 00164: val_loss did not improve from 1.63588
# Epoch 165/200
# 167/167 [==============================] - 61s 365ms/step - loss: 0.3897 - acc: 0.8043 - val_loss: 1.7307 - val_acc: 0.5719
#
# Epoch 00165: val_loss did not improve from 1.63588
# Epoch 166/200
# 167/167 [==============================] - 61s 366ms/step - loss: 0.4027 - acc: 0.8011 - val_loss: 1.7244 - val_acc: 0.5871
#
# Epoch 00166: val_loss did not improve from 1.63588
# Epoch 167/200
# 167/167 [==============================] - 62s 367ms/step - loss: 0.3714 - acc: 0.8043 - val_loss: 1.7151 - val_acc: 0.5821
#
# Epoch 00167: val_loss did not improve from 1.63588
# Epoch 168/200
# 167/167 [==============================] - 61s 366ms/step - loss: 0.3739 - acc: 0.8060 - val_loss: 1.6772 - val_acc: 0.5651
#
# Epoch 00168: val_loss did not improve from 1.63588
# Epoch 169/200
# 167/167 [==============================] - 61s 366ms/step - loss: 0.3807 - acc: 0.7977 - val_loss: 1.7556 - val_acc: 0.5719
#
# Epoch 00169: val_loss did not improve from 1.63588
# Epoch 170/200
# 167/167 [==============================] - 61s 366ms/step - loss: 0.3686 - acc: 0.8150 - val_loss: 1.7505 - val_acc: 0.5651
#
# Epoch 00170: val_loss did not improve from 1.63588
# Epoch 171/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3777 - acc: 0.8133 - val_loss: 1.6785 - val_acc: 0.5635
#
# Epoch 00171: val_loss did not improve from 1.63588
# Epoch 172/200
# 167/167 [==============================] - 62s 370ms/step - loss: 0.3828 - acc: 0.8068 - val_loss: 1.7422 - val_acc: 0.5736
#
# Epoch 00172: val_loss did not improve from 1.63588
# Epoch 173/200
# 167/167 [==============================] - 62s 370ms/step - loss: 0.3856 - acc: 0.8083 - val_loss: 1.7671 - val_acc: 0.5668
#
# Epoch 00173: val_loss did not improve from 1.63588
# Epoch 174/200
# 167/167 [==============================] - 62s 369ms/step - loss: 0.3801 - acc: 0.8086 - val_loss: 1.7856 - val_acc: 0.5702
#
# Epoch 00174: val_loss did not improve from 1.63588
# Epoch 175/200
# 167/167 [==============================] - 62s 372ms/step - loss: 0.3659 - acc: 0.8150 - val_loss: 1.7592 - val_acc: 0.5736
#
# Epoch 00175: val_loss did not improve from 1.63588
# Epoch 176/200
# 167/167 [==============================] - 62s 370ms/step - loss: 0.3701 - acc: 0.8113 - val_loss: 1.7179 - val_acc: 0.5584
#
# Epoch 00176: val_loss did not improve from 1.63588
# Epoch 177/200
# 167/167 [==============================] - 63s 374ms/step - loss: 0.3722 - acc: 0.8103 - val_loss: 1.7199 - val_acc: 0.5651
#
# Epoch 00177: val_loss did not improve from 1.63588
# Epoch 178/200
# 167/167 [==============================] - 62s 367ms/step - loss: 0.3757 - acc: 0.8068 - val_loss: 1.7582 - val_acc: 0.5584
#
# Epoch 00178: val_loss did not improve from 1.63588
# Epoch 179/200
# 167/167 [==============================] - 62s 369ms/step - loss: 0.3862 - acc: 0.8079 - val_loss: 1.7772 - val_acc: 0.5651
#
# Epoch 00179: val_loss did not improve from 1.63588
# Epoch 180/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3695 - acc: 0.8113 - val_loss: 1.7198 - val_acc: 0.5719
#
# Epoch 00180: val_loss did not improve from 1.63588
# Epoch 181/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3897 - acc: 0.8017 - val_loss: 1.7035 - val_acc: 0.5719
#
# Epoch 00181: val_loss did not improve from 1.63588
# Epoch 182/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3785 - acc: 0.8088 - val_loss: 1.7635 - val_acc: 0.5533
#
# Epoch 00182: val_loss did not improve from 1.63588
# Epoch 183/200
# 167/167 [==============================] - 62s 367ms/step - loss: 0.3844 - acc: 0.8083 - val_loss: 1.7622 - val_acc: 0.5804
#
# Epoch 00183: val_loss did not improve from 1.63588
# Epoch 184/200
# 167/167 [==============================] - 62s 369ms/step - loss: 0.3771 - acc: 0.8041 - val_loss: 1.7823 - val_acc: 0.5668
#
# Epoch 00184: val_loss did not improve from 1.63588
# Epoch 185/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3668 - acc: 0.8126 - val_loss: 1.7911 - val_acc: 0.5736
#
# Epoch 00185: val_loss did not improve from 1.63588
# Epoch 186/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3647 - acc: 0.8162 - val_loss: 1.7106 - val_acc: 0.5905
#
# Epoch 00186: val_loss did not improve from 1.63588
# Epoch 187/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3884 - acc: 0.8077 - val_loss: 1.7691 - val_acc: 0.5804
#
# Epoch 00187: val_loss did not improve from 1.63588
# Epoch 188/200
# 167/167 [==============================] - 62s 369ms/step - loss: 0.3726 - acc: 0.8055 - val_loss: 1.7861 - val_acc: 0.5702
#
# Epoch 00188: val_loss did not improve from 1.63588
# Epoch 189/200
# 167/167 [==============================] - 62s 369ms/step - loss: 0.3831 - acc: 0.8036 - val_loss: 1.7967 - val_acc: 0.5567
#
# Epoch 00189: val_loss did not improve from 1.63588
# Epoch 190/200
# 167/167 [==============================] - 62s 369ms/step - loss: 0.3772 - acc: 0.8085 - val_loss: 1.7648 - val_acc: 0.5736
#
# Epoch 00190: val_loss did not improve from 1.63588
# Epoch 191/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3705 - acc: 0.8053 - val_loss: 1.6761 - val_acc: 0.5871
#
# Epoch 00191: val_loss did not improve from 1.63588
# Epoch 192/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3817 - acc: 0.8096 - val_loss: 1.7905 - val_acc: 0.5685
#
# Epoch 00192: val_loss did not improve from 1.63588
# Epoch 193/200
# 167/167 [==============================] - 61s 367ms/step - loss: 0.3708 - acc: 0.8105 - val_loss: 1.7996 - val_acc: 0.5736
#
# Epoch 00193: val_loss did not improve from 1.63588
# Epoch 194/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3692 - acc: 0.8028 - val_loss: 1.7256 - val_acc: 0.5668
#
# Epoch 00194: val_loss did not improve from 1.63588
# Epoch 195/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3772 - acc: 0.8051 - val_loss: 1.6793 - val_acc: 0.5651
#
# Epoch 00195: val_loss did not improve from 1.63588
# Epoch 196/200
# 167/167 [==============================] - 62s 369ms/step - loss: 0.3905 - acc: 0.8079 - val_loss: 1.7685 - val_acc: 0.5499
#
# Epoch 00196: val_loss did not improve from 1.63588
# Epoch 197/200
# 167/167 [==============================] - 61s 367ms/step - loss: 0.3797 - acc: 0.8120 - val_loss: 1.7141 - val_acc: 0.5821
#
# Epoch 00197: val_loss did not improve from 1.63588
# Epoch 198/200
# 167/167 [==============================] - 62s 367ms/step - loss: 0.3614 - acc: 0.8182 - val_loss: 1.6954 - val_acc: 0.5601
#
# Epoch 00198: val_loss did not improve from 1.63588
# Epoch 199/200
# 167/167 [==============================] - 62s 368ms/step - loss: 0.3730 - acc: 0.8068 - val_loss: 1.7830 - val_acc: 0.5584
#
# Epoch 00199: val_loss did not improve from 1.63588
# Epoch 200/200
# 167/167 [==============================] - 63s 377ms/step - loss: 0.3639 - acc: 0.8188 - val_loss: 1.7247 - val_acc: 0.5854
#
# Epoch 00200: val_loss did not improve from 1.63588

# %%
X_test = pd.read_csv("test.csv")

DATAGEN_TEST = ImageDataGenerator(
    rescale=1./255,
    data_format="channels_last"
)

TEST_GENERATOR = DATAGEN_TEST.flow_from_dataframe(
    dataframe=X_test,
    x_col='img_path',
    y_col=None,
    target_size=(244, 244),
    color_mode='rgb',
    class_mode=None,
    batch_size=32,
    shuffle=False
)

model.load_weights('model/Googlenet-023-0.7189-1.6359.hdf5')

TEST_Prediction = model.predict(TEST_GENERATOR, verbose=1)
# Out:
# Found 12670 validated image filenames.
# 396/396 [==============================] - 132s 332ms/step

# %%
artist_num = np.argmax(TEST_Prediction, axis=1)
num_list = pd.DataFrame(artist_num, columns=['artist'])

artist_name = []
for i in num_list['artist']:
    artist_name.append(artist_test_dic[i])

last_ans = pd.read_csv("sample_submission.csv")

last_ans.rename(columns={'artist':'artist_name'}, inplace=True)

last_ans['artist'] = artist_name
last_ans.drop('artist_name', axis=1, inplace=True)

last_ans.to_csv("Googlenet_200_batchnormalization_minlrfix.csv", index=False)
