# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8681932127264852755
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5726273536
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4912257111389517349
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50, VGG16, InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.preprocessing import LabelEncoder

def cutout(image, label, probability=0.5):
    if np.random.rand() < probability:
        h, w = image.shape[:2]
        size = w // 4
        x1 = np.random.randint(w)
        y1 = np.random.randint(h)
        x2 = np.clip(x1 + size, 0, w)
        y2 = np.clip(y1 + size, 0, h)
        image[y1:y2, x1:x2 :] = 0
    return image, label


df = pd.read_csv("train.csv")
label_encoder = LabelEncoder()
artist_df = df.copy()
artist_train = label_encoder.fit_transform(df['artist'].values)


artist_df['num'] = artist_train
artist_df = artist_df.drop('id', axis=1)
artist_df = artist_df.drop('img_path', axis=1)


artist_df.set_index('num', inplace=True)
artist_df = artist_df.sort_index()


artist_test_dic = artist_df['artist'].to_dict()


# 데이터 노이즈 수정
df.loc[df['id'] == 3896, 'artist'] = 'Titian'
df.loc[df['id'] == 3986, 'artist'] = 'Alfred Sisley'

X_train = df

#X_train, X_val, y_train, y_val = train_test_split(df, df['artist'].values, test_size=0.1)

print("Number of X_train: ", len(X_train))
# Out:
# Number of X_train:  5911

# %%
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(artist_train), y=artist_train)
class_weights_dict = {i: class_weights[i] for i in range(len(class_weights))}

display(class_weights_dict)

base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(244,244,3), input_tensor=None, pooling=None)

x = GlobalAveragePooling2D()(base_model.output)
predictions = Dense(50, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

LearningRate = 1e-3

optimizer = Adam(learning_rate=LearningRate)

model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['acc'])

CP = ModelCheckpoint(filepath='model/' +
                     'Googlenet-Sigmoid-{epoch:03d}-{loss:.4f}-{val_loss:.4f}.hdf5',
                     monitor='val_loss', verbose=1, save_best_only=True, mode='min')

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1, min_lr=0.00005)
CALLBACK = [CP, LR]

early_stopping = EarlyStopping(
    monitor='val_acc',
    min_delta=0.001,
    patience=10,
    verbose=1,
    restore_best_weights=True,
)


DATAGEN_TRAIN = ImageDataGenerator(
    rescale=1/255.0,
    #rotation_range=20,
    width_shift_range=0.25,
    height_shift_range=0.25,
    #shear_range=0.2,
    zoom_range=0.25,
    horizontal_flip=True,
    #vertical_flip=True,
    data_format="channels_last",
    validation_split=0.10
)


TRAIN_GENERATOR = DATAGEN_TRAIN.flow_from_dataframe(
    dataframe=X_train, x_col='img_path', y_col='artist',
    target_size=(244, 244), 
    class_mode='categorical',
    batch_size=32, shuffle=True,
    subset="training",
    preprocessing_function=cutout
)

VALID_GENERATOR = DATAGEN_TRAIN.flow_from_dataframe(
    dataframe=X_train, x_col='img_path', y_col='artist',
    target_size=(244, 244), 
    class_mode='categorical',
    batch_size=32, shuffle=True,
    subset="validation",
    preprocessing_function=cutout
)
# Out:
# {0: 0.5373636363636364,
#  1: 0.7208536585365853,
#  2: 0.8956060606060606,
#  3: 1.5975675675675676,
#  4: 0.8956060606060606,
#  5: 1.8471875,
#  6: 3.694375,
#  7: 2.003728813559322,
#  8: 2.3644,
#  9: 1.4595061728395062,
#  10: 0.24126530612244898,
#  11: 1.906774193548387,
#  12: 2.686818181818182,
#  13: 1.8187692307692307,
#  14: 4.546923076923077,
#  15: 0.5795098039215686,
#  16: 1.4073809523809524,
#  17: 3.9406666666666665,
#  18: 1.6419444444444444,
#  19: 1.7133333333333334,
#  20: 2.814761904761905,
#  21: 0.9770247933884297,
#  22: 2.2734615384615386,
#  23: 1.9380327868852458,
#  24: 1.028,
#  25: 5.62952380952381,
#  26: 1.8471875,
#  27: 1.5555263157894736,
#  28: 1.299120879120879,
#  29: 1.1704950495049504,
#  30: 0.6833526011560693,
#  31: 3.4770588235294118,
#  32: 1.001864406779661,
#  33: 0.39016501650165014,
#  34: 3.5824242424242425,
#  35: 0.5373636363636364,
#  36: 0.8325352112676057,
#  37: 1.218762886597938,
#  38: 0.5073819742489271,
#  39: 2.003728813559322,
#  40: 1.3908235294117648,
#  41: 1.6194520547945206,
#  42: 0.6531491712707183,
#  43: 0.862919708029197,
#  44: 1.1941414141414142,
#  45: 0.9851666666666666,
#  46: 0.6833526011560693,
#  47: 1.9703333333333333,
#  48: 0.18794912559618443,
#  49: 2.686818181818182}
# Found 5320 validated image filenames belonging to 50 classes.
# Found 591 validated image filenames belonging to 50 classes.

# %%
history = model.fit(
    TRAIN_GENERATOR,
    epochs=100,
    callbacks=CALLBACK,
    shuffle=True,
    validation_data=VALID_GENERATOR,
    class_weight=class_weights_dict
)
# Out:
# WARNING:tensorflow:From C:\Users\User\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 167/167 [==============================] - 120s 664ms/step - loss: 3.4877 - acc: 0.1068 - val_loss: 13.2059 - val_acc: 0.0372
#
# Epoch 00001: val_loss improved from inf to 13.20595, saving model to model\Googlenet-Sigmoid-001-3.4877-13.2059.hdf5
# Epoch 2/100
# 167/167 [==============================] - 60s 358ms/step - loss: 2.9879 - acc: 0.1803 - val_loss: 33.8470 - val_acc: 0.0237
#
# Epoch 00002: val_loss did not improve from 13.20595
# Epoch 3/100
# 167/167 [==============================] - 60s 359ms/step - loss: 2.7180 - acc: 0.2325 - val_loss: 7.3329 - val_acc: 0.0609
#
# Epoch 00003: val_loss improved from 13.20595 to 7.33287, saving model to model\Googlenet-Sigmoid-003-2.7180-7.3329.hdf5
# Epoch 4/100
# 167/167 [==============================] - 60s 356ms/step - loss: 2.4665 - acc: 0.2797 - val_loss: 3.7366 - val_acc: 0.1946
#
# Epoch 00004: val_loss improved from 7.33287 to 3.73663, saving model to model\Googlenet-Sigmoid-004-2.4665-3.7366.hdf5
# Epoch 5/100
# 167/167 [==============================] - 60s 356ms/step - loss: 2.2716 - acc: 0.3184 - val_loss: 4.7527 - val_acc: 0.1354
#
# Epoch 00005: val_loss did not improve from 3.73663
# Epoch 6/100
# 167/167 [==============================] - 60s 355ms/step - loss: 2.1237 - acc: 0.3472 - val_loss: 4.7569 - val_acc: 0.1354
#
# Epoch 00006: val_loss did not improve from 3.73663
# Epoch 7/100
# 167/167 [==============================] - 60s 355ms/step - loss: 2.0223 - acc: 0.3677 - val_loss: 4.0328 - val_acc: 0.1929
#
# Epoch 00007: val_loss did not improve from 3.73663
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/100
# 167/167 [==============================] - 60s 355ms/step - loss: 1.5993 - acc: 0.4611 - val_loss: 2.1935 - val_acc: 0.3875
#
# Epoch 00008: val_loss improved from 3.73663 to 2.19348, saving model to model\Googlenet-Sigmoid-008-1.5993-2.1935.hdf5
# Epoch 9/100
# 167/167 [==============================] - 60s 357ms/step - loss: 1.4713 - acc: 0.4863 - val_loss: 2.1450 - val_acc: 0.4264
#
# Epoch 00009: val_loss improved from 2.19348 to 2.14499, saving model to model\Googlenet-Sigmoid-009-1.4713-2.1450.hdf5
# Epoch 10/100
# 167/167 [==============================] - 60s 356ms/step - loss: 1.3613 - acc: 0.5222 - val_loss: 2.7657 - val_acc: 0.3452
#
# Epoch 00010: val_loss did not improve from 2.14499
# Epoch 11/100
# 167/167 [==============================] - 60s 356ms/step - loss: 1.2906 - acc: 0.5336 - val_loss: 2.2499 - val_acc: 0.4349
#
# Epoch 00011: val_loss did not improve from 2.14499
# Epoch 12/100
# 167/167 [==============================] - 60s 356ms/step - loss: 1.2013 - acc: 0.5635 - val_loss: 2.6433 - val_acc: 0.3824
#
# Epoch 00012: val_loss did not improve from 2.14499
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 13/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.9925 - acc: 0.6194 - val_loss: 1.7747 - val_acc: 0.4958
#
# Epoch 00013: val_loss improved from 2.14499 to 1.77474, saving model to model\Googlenet-Sigmoid-013-0.9925-1.7747.hdf5
# Epoch 14/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.8672 - acc: 0.6474 - val_loss: 1.8879 - val_acc: 0.4873
#
# Epoch 00014: val_loss did not improve from 1.77474
# Epoch 15/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.8041 - acc: 0.6648 - val_loss: 1.9192 - val_acc: 0.5025
#
# Epoch 00015: val_loss did not improve from 1.77474
# Epoch 16/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.7838 - acc: 0.6754 - val_loss: 1.9723 - val_acc: 0.4924
#
# Epoch 00016: val_loss did not improve from 1.77474
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 17/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.6297 - acc: 0.7194 - val_loss: 1.6859 - val_acc: 0.5364
#
# Epoch 00017: val_loss improved from 1.77474 to 1.68591, saving model to model\Googlenet-Sigmoid-017-0.6297-1.6859.hdf5
# Epoch 18/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.5424 - acc: 0.7521 - val_loss: 1.7325 - val_acc: 0.5499
#
# Epoch 00018: val_loss did not improve from 1.68591
# Epoch 19/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.5204 - acc: 0.7665 - val_loss: 1.7233 - val_acc: 0.5922
#
# Epoch 00019: val_loss did not improve from 1.68591
# Epoch 20/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.4755 - acc: 0.7771 - val_loss: 1.7387 - val_acc: 0.5635
#
# Epoch 00020: val_loss did not improve from 1.68591
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 21/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.3984 - acc: 0.8024 - val_loss: 1.6917 - val_acc: 0.5753
#
# Epoch 00021: val_loss did not improve from 1.68591
# Epoch 22/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.3600 - acc: 0.8103 - val_loss: 1.7584 - val_acc: 0.5871
#
# Epoch 00022: val_loss did not improve from 1.68591
# Epoch 23/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.3454 - acc: 0.8248 - val_loss: 1.7583 - val_acc: 0.5854
#
# Epoch 00023: val_loss did not improve from 1.68591
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5e-05.
# Epoch 24/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.2989 - acc: 0.8434 - val_loss: 1.7101 - val_acc: 0.5922
#
# Epoch 00024: val_loss did not improve from 1.68591
# Epoch 25/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.2929 - acc: 0.8485 - val_loss: 1.7797 - val_acc: 0.5973
#
# Epoch 00025: val_loss did not improve from 1.68591
# Epoch 26/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.2848 - acc: 0.8536 - val_loss: 1.8085 - val_acc: 0.6041
#
# Epoch 00026: val_loss did not improve from 1.68591
# Epoch 27/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.2854 - acc: 0.8462 - val_loss: 1.8547 - val_acc: 0.5770
#
# Epoch 00027: val_loss did not improve from 1.68591
# Epoch 28/100
# 167/167 [==============================] - 60s 358ms/step - loss: 0.2434 - acc: 0.8618 - val_loss: 1.7688 - val_acc: 0.6108
#
# Epoch 00028: val_loss did not improve from 1.68591
# Epoch 29/100
# 167/167 [==============================] - 60s 357ms/step - loss: 0.2552 - acc: 0.8662 - val_loss: 1.7356 - val_acc: 0.6007
#
# Epoch 00029: val_loss did not improve from 1.68591
# Epoch 30/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.2418 - acc: 0.8758 - val_loss: 1.8208 - val_acc: 0.5905
#
# Epoch 00030: val_loss did not improve from 1.68591
# Epoch 31/100
# 167/167 [==============================] - 60s 357ms/step - loss: 0.2266 - acc: 0.8786 - val_loss: 1.9316 - val_acc: 0.5922
#
# Epoch 00031: val_loss did not improve from 1.68591
# Epoch 32/100
# 167/167 [==============================] - 60s 357ms/step - loss: 0.2157 - acc: 0.8868 - val_loss: 1.6949 - val_acc: 0.6261
#
# Epoch 00032: val_loss did not improve from 1.68591
# Epoch 33/100
# 167/167 [==============================] - 60s 359ms/step - loss: 0.1951 - acc: 0.8887 - val_loss: 1.7791 - val_acc: 0.6210
#
# Epoch 00033: val_loss did not improve from 1.68591
# Epoch 34/100
# 167/167 [==============================] - 60s 357ms/step - loss: 0.1979 - acc: 0.8964 - val_loss: 1.7867 - val_acc: 0.6125
#
# Epoch 00034: val_loss did not improve from 1.68591
# Epoch 35/100
# 167/167 [==============================] - 60s 357ms/step - loss: 0.1912 - acc: 0.8844 - val_loss: 1.8103 - val_acc: 0.6294
#
# Epoch 00035: val_loss did not improve from 1.68591
# Epoch 36/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.1737 - acc: 0.8977 - val_loss: 1.8571 - val_acc: 0.6159
#
# Epoch 00036: val_loss did not improve from 1.68591
# Epoch 37/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.1744 - acc: 0.9000 - val_loss: 1.7606 - val_acc: 0.6362
#
# Epoch 00037: val_loss did not improve from 1.68591
# Epoch 38/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.1713 - acc: 0.9043 - val_loss: 1.7759 - val_acc: 0.6193
#
# Epoch 00038: val_loss did not improve from 1.68591
# Epoch 39/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.1490 - acc: 0.9126 - val_loss: 1.8244 - val_acc: 0.5939
#
# Epoch 00039: val_loss did not improve from 1.68591
# Epoch 40/100
# 167/167 [==============================] - 60s 357ms/step - loss: 0.1498 - acc: 0.9060 - val_loss: 1.8243 - val_acc: 0.6159
#
# Epoch 00040: val_loss did not improve from 1.68591
# Epoch 41/100
# 167/167 [==============================] - 60s 357ms/step - loss: 0.1597 - acc: 0.9118 - val_loss: 1.8900 - val_acc: 0.6041
#
# Epoch 00041: val_loss did not improve from 1.68591
# Epoch 42/100
# 167/167 [==============================] - 60s 357ms/step - loss: 0.1414 - acc: 0.9180 - val_loss: 1.8328 - val_acc: 0.6176
#
# Epoch 00042: val_loss did not improve from 1.68591
# Epoch 43/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.1444 - acc: 0.9133 - val_loss: 1.8640 - val_acc: 0.6007
#
# Epoch 00043: val_loss did not improve from 1.68591
# Epoch 44/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.1415 - acc: 0.9150 - val_loss: 1.8778 - val_acc: 0.6193
#
# Epoch 00044: val_loss did not improve from 1.68591
# Epoch 45/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.1410 - acc: 0.9201 - val_loss: 1.8375 - val_acc: 0.6379
#
# Epoch 00045: val_loss did not improve from 1.68591
# Epoch 46/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.1408 - acc: 0.9212 - val_loss: 1.9415 - val_acc: 0.6159
#
# Epoch 00046: val_loss did not improve from 1.68591
# Epoch 47/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.1306 - acc: 0.9226 - val_loss: 1.8704 - val_acc: 0.5990
#
# Epoch 00047: val_loss did not improve from 1.68591
# Epoch 48/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.1211 - acc: 0.9286 - val_loss: 2.0502 - val_acc: 0.6007
#
# Epoch 00048: val_loss did not improve from 1.68591
# Epoch 49/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.1084 - acc: 0.9357 - val_loss: 1.9503 - val_acc: 0.6125
#
# Epoch 00049: val_loss did not improve from 1.68591
# Epoch 50/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.1194 - acc: 0.9376 - val_loss: 1.9037 - val_acc: 0.6193
#
# Epoch 00050: val_loss did not improve from 1.68591
# Epoch 51/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.1281 - acc: 0.9353 - val_loss: 1.9294 - val_acc: 0.6244
#
# Epoch 00051: val_loss did not improve from 1.68591
# Epoch 52/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.1014 - acc: 0.9427 - val_loss: 1.8464 - val_acc: 0.6379
#
# Epoch 00052: val_loss did not improve from 1.68591
# Epoch 53/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.1106 - acc: 0.9367 - val_loss: 1.8538 - val_acc: 0.6261
#
# Epoch 00053: val_loss did not improve from 1.68591
# Epoch 54/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.1093 - acc: 0.9363 - val_loss: 1.8260 - val_acc: 0.6447
#
# Epoch 00054: val_loss did not improve from 1.68591
# Epoch 55/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.1161 - acc: 0.9389 - val_loss: 2.0336 - val_acc: 0.6277
#
# Epoch 00055: val_loss did not improve from 1.68591
# Epoch 56/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.1051 - acc: 0.9461 - val_loss: 1.8355 - val_acc: 0.6514
#
# Epoch 00056: val_loss did not improve from 1.68591
# Epoch 57/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.1058 - acc: 0.9385 - val_loss: 1.8095 - val_acc: 0.6362
#
# Epoch 00057: val_loss did not improve from 1.68591
# Epoch 58/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0812 - acc: 0.9506 - val_loss: 1.8825 - val_acc: 0.6514
#
# Epoch 00058: val_loss did not improve from 1.68591
# Epoch 59/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0939 - acc: 0.9455 - val_loss: 1.8036 - val_acc: 0.6430
#
# Epoch 00059: val_loss did not improve from 1.68591
# Epoch 60/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0809 - acc: 0.9575 - val_loss: 1.7471 - val_acc: 0.6430
#
# Epoch 00060: val_loss did not improve from 1.68591
# Epoch 61/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0901 - acc: 0.9470 - val_loss: 1.8835 - val_acc: 0.6514
#
# Epoch 00061: val_loss did not improve from 1.68591
# Epoch 62/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0821 - acc: 0.9504 - val_loss: 1.9618 - val_acc: 0.6345
#
# Epoch 00062: val_loss did not improve from 1.68591
# Epoch 63/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0904 - acc: 0.9498 - val_loss: 1.9161 - val_acc: 0.6311
#
# Epoch 00063: val_loss did not improve from 1.68591
# Epoch 64/100
# 167/167 [==============================] - 61s 367ms/step - loss: 0.0814 - acc: 0.9575 - val_loss: 1.8935 - val_acc: 0.6497
#
# Epoch 00064: val_loss did not improve from 1.68591
# Epoch 65/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0821 - acc: 0.9543 - val_loss: 1.8289 - val_acc: 0.6701
#
# Epoch 00065: val_loss did not improve from 1.68591
# Epoch 66/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0920 - acc: 0.9479 - val_loss: 1.9472 - val_acc: 0.6430
#
# Epoch 00066: val_loss did not improve from 1.68591
# Epoch 67/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0783 - acc: 0.9538 - val_loss: 1.8744 - val_acc: 0.6345
#
# Epoch 00067: val_loss did not improve from 1.68591
# Epoch 68/100
# 167/167 [==============================] - 60s 358ms/step - loss: 0.0643 - acc: 0.9581 - val_loss: 1.9467 - val_acc: 0.6159
#
# Epoch 00068: val_loss did not improve from 1.68591
# Epoch 69/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0719 - acc: 0.9613 - val_loss: 1.9806 - val_acc: 0.6125
#
# Epoch 00069: val_loss did not improve from 1.68591
# Epoch 70/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0644 - acc: 0.9626 - val_loss: 1.9079 - val_acc: 0.6227
#
# Epoch 00070: val_loss did not improve from 1.68591
# Epoch 71/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0678 - acc: 0.9615 - val_loss: 1.7812 - val_acc: 0.6650
#
# Epoch 00071: val_loss did not improve from 1.68591
# Epoch 72/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.0605 - acc: 0.9660 - val_loss: 1.7337 - val_acc: 0.6684
#
# Epoch 00072: val_loss did not improve from 1.68591
# Epoch 73/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0603 - acc: 0.9650 - val_loss: 1.8317 - val_acc: 0.6565
#
# Epoch 00073: val_loss did not improve from 1.68591
# Epoch 74/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0610 - acc: 0.9626 - val_loss: 1.9521 - val_acc: 0.6345
#
# Epoch 00074: val_loss did not improve from 1.68591
# Epoch 75/100
# 167/167 [==============================] - 60s 357ms/step - loss: 0.0897 - acc: 0.9553 - val_loss: 2.1385 - val_acc: 0.6041
#
# Epoch 00075: val_loss did not improve from 1.68591
# Epoch 76/100
# 167/167 [==============================] - 60s 358ms/step - loss: 0.0694 - acc: 0.9596 - val_loss: 1.9827 - val_acc: 0.6244
#
# Epoch 00076: val_loss did not improve from 1.68591
# Epoch 77/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0612 - acc: 0.9626 - val_loss: 1.8675 - val_acc: 0.6464
#
# Epoch 00077: val_loss did not improve from 1.68591
# Epoch 78/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0628 - acc: 0.9660 - val_loss: 1.9356 - val_acc: 0.6379
#
# Epoch 00078: val_loss did not improve from 1.68591
# Epoch 79/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0652 - acc: 0.9688 - val_loss: 2.0615 - val_acc: 0.6311
#
# Epoch 00079: val_loss did not improve from 1.68591
# Epoch 80/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0671 - acc: 0.9650 - val_loss: 1.8822 - val_acc: 0.6430
#
# Epoch 00080: val_loss did not improve from 1.68591
# Epoch 81/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0605 - acc: 0.9645 - val_loss: 1.8668 - val_acc: 0.6379
#
# Epoch 00081: val_loss did not improve from 1.68591
# Epoch 82/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.0603 - acc: 0.9658 - val_loss: 2.0052 - val_acc: 0.6396
#
# Epoch 00082: val_loss did not improve from 1.68591
# Epoch 83/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0633 - acc: 0.9613 - val_loss: 1.8231 - val_acc: 0.6548
#
# Epoch 00083: val_loss did not improve from 1.68591
# Epoch 84/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0792 - acc: 0.9583 - val_loss: 2.1416 - val_acc: 0.6058
#
# Epoch 00084: val_loss did not improve from 1.68591
# Epoch 85/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.0617 - acc: 0.9660 - val_loss: 1.9227 - val_acc: 0.6261
#
# Epoch 00085: val_loss did not improve from 1.68591
# Epoch 86/100
# 167/167 [==============================] - 59s 354ms/step - loss: 0.0642 - acc: 0.9682 - val_loss: 1.8281 - val_acc: 0.6582
#
# Epoch 00086: val_loss did not improve from 1.68591
# Epoch 87/100
# 167/167 [==============================] - 59s 354ms/step - loss: 0.0646 - acc: 0.9624 - val_loss: 2.0825 - val_acc: 0.6430
#
# Epoch 00087: val_loss did not improve from 1.68591
# Epoch 88/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.0593 - acc: 0.9654 - val_loss: 2.0246 - val_acc: 0.6294
#
# Epoch 00088: val_loss did not improve from 1.68591
# Epoch 89/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0456 - acc: 0.9733 - val_loss: 1.8527 - val_acc: 0.6582
#
# Epoch 00089: val_loss did not improve from 1.68591
# Epoch 90/100
# 167/167 [==============================] - 60s 355ms/step - loss: 0.0446 - acc: 0.9750 - val_loss: 2.0089 - val_acc: 0.6345
#
# Epoch 00090: val_loss did not improve from 1.68591
# Epoch 91/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0498 - acc: 0.9701 - val_loss: 1.9005 - val_acc: 0.6396
#
# Epoch 00091: val_loss did not improve from 1.68591
# Epoch 92/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0446 - acc: 0.9733 - val_loss: 1.9358 - val_acc: 0.6481
#
# Epoch 00092: val_loss did not improve from 1.68591
# Epoch 93/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0463 - acc: 0.9726 - val_loss: 1.8544 - val_acc: 0.6717
#
# Epoch 00093: val_loss did not improve from 1.68591
# Epoch 94/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0466 - acc: 0.9737 - val_loss: 1.9063 - val_acc: 0.6582
#
# Epoch 00094: val_loss did not improve from 1.68591
# Epoch 95/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0548 - acc: 0.9707 - val_loss: 1.8721 - val_acc: 0.6548
#
# Epoch 00095: val_loss did not improve from 1.68591
# Epoch 96/100
# 167/167 [==============================] - 59s 355ms/step - loss: 0.0479 - acc: 0.9754 - val_loss: 2.0466 - val_acc: 0.6379
#
# Epoch 00096: val_loss did not improve from 1.68591
# Epoch 97/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0527 - acc: 0.9703 - val_loss: 1.9775 - val_acc: 0.6447
#
# Epoch 00097: val_loss did not improve from 1.68591
# Epoch 98/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0358 - acc: 0.9776 - val_loss: 1.9392 - val_acc: 0.6362
#
# Epoch 00098: val_loss did not improve from 1.68591
# Epoch 99/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0439 - acc: 0.9761 - val_loss: 2.1462 - val_acc: 0.6159
#
# Epoch 00099: val_loss did not improve from 1.68591
# Epoch 100/100
# 167/167 [==============================] - 60s 356ms/step - loss: 0.0421 - acc: 0.9786 - val_loss: 2.1149 - val_acc: 0.6345
#
# Epoch 00100: val_loss did not improve from 1.68591

# %%
X_test = pd.read_csv("test.csv")

DATAGEN_TEST = ImageDataGenerator(
    rescale=1./255,
    data_format="channels_last"
)

TEST_GENERATOR = DATAGEN_TEST.flow_from_dataframe(
    dataframe=X_test,
    x_col='img_path',
    y_col=None,
    target_size=(244, 244),
    color_mode='rgb',
    class_mode=None,
    batch_size=32,
    shuffle=False
)

TEST_Prediction = model.predict(TEST_GENERATOR, verbose=1)
# Out:
# Found 12670 validated image filenames.
# 396/396 [==============================] - 132s 333ms/step

# %%
artist_num = np.argmax(TEST_Prediction, axis=1)
num_list = pd.DataFrame(artist_num, columns=['artist'])

artist_name = []
for i in num_list['artist']:
    artist_name.append(artist_test_dic[i])

last_ans = pd.read_csv("sample_submission.csv")

last_ans.rename(columns={'artist':'artist_name'}, inplace=True)

last_ans['artist'] = artist_name
last_ans.drop('artist_name', axis=1, inplace=True)

last_ans.to_csv("Googlenet_100_cutout.csv", index=False)
